# %% [markdown]
# # 🌍 Geospatial Machine Learning for Air Pollution Prediction
# ## Multivariate Environmental Data — Port Harcourt, Nigeria (2023–2025)
#
# **Journal target:** Environmental Science and Pollution Research (Springer)
# **Study area:** 48 monitoring stations, Port Harcourt, Rivers State, Nigeria
# **Period:** August 2023 – January 2025 · **Dataset:** 576 station-month observations
#
# ---
# ### 📌 Table of Contents
# 1. [Dataset Overview](#1-dataset-overview)
# 2. [Descriptive Statistics](#2-descriptive-statistics)
# 3. [Temporal Trends](#3-temporal-trends)
# 4. [Spatial Analysis](#4-spatial-analysis)
# 5. [Statistical Tests](#5-statistical-tests)
# 6. [Correlation Analysis](#6-correlation-analysis)
# 7. [Machine Learning Results](#7-machine-learning-results)
# 8. [Feature Importance](#8-feature-importance)
# 9. [Observed vs Predicted](#9-observed-vs-predicted)
# 10. [Key Findings Summary](#10-key-findings-summary)

# %% [markdown]
# ## 1. Dataset Overview

# %%
# Dataset overview
# Out:
# Total observations : 576
# Monitoring stations: 48
# Months covered     : 12  (AUGUST 2023 → JANUARY 2025)
# Target pollutants  : CO₂, N₂O, CH₄, O₃, CO
# Predictor features : Latitude, Longitude, Month, Temperature, Humidity, Wind Speed, Rainfall
# Missing values     : 0
# Geographic extent  : 4.74–4.95°N, 6.92–7.08°E (Port Harcourt, Nigeria)

# %% [markdown]
# ## 2. Descriptive Statistics

# %%
# Descriptive statistics
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CO₂ (ppm)</th>
#       <td>576.0</td>
#       <td>764.3980</td>
#       <td>33.5990</td>
#       <td>607.4000</td>
#       <td>745.9000</td>
#       <td>764.4000</td>
#       <td>782.1333</td>
#       <td>879.3000</td>
#     </tr>
#     <tr>
#       <th>N₂O (ppm)</th>
#       <td>576.0</td>
#       <td>0.0703</td>
#       <td>0.0121</td>
#       <td>0.0243</td>
#       <td>0.0640</td>
#       <td>0.0700</td>
#       <td>0.0768</td>
#       <td>0.1107</td>
#     </tr>
#     <tr>
#       <th>CH₄ (ppm)</th>
#       <td>576.0</td>
#       <td>4.9109</td>
#       <td>4.2043</td>
#       <td>1.0033</td>
#       <td>1.9367</td>
#       <td>4.0233</td>
# ...

# %% [markdown]
# ## 3. Temporal Trends

# %%
# Figure 1 — Temporal trends with linear fit. Blue=2023, Red=2024-25.

# %% [markdown]
# ### Monthly Mean Concentrations

# %%
# Monthly means
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CO₂</th>
#       <th>N₂O</th>
#       <th>CH₄</th>
#       <th>O₃</th>
#       <th>CO</th>
#       <th>Temp (°C)</th>
#       <th>Humidity (%)</th>
#     </tr>
#     <tr>
#       <th>Month</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AUGUST 2023</th>
#       <td>737.827</td>
#       <td>0.060</td>
#       <td>2.159</td>
#       <td>0.111</td>
#       <td>16.582</td>
#       <td>28.741</td>
#       <td>81.757</td>
#     </tr>
#     <tr>
#       <th>SEPTEMBER 2023</th>
#       <td>762.635</td>
#       <td>0.069</td>
#       <td>2.136</td>
#       <td>0.124</td>
#       <td>16.882</td>
#       <td>29.431</td>
#       <td>80.986</td>
#     </tr>
#     <tr>
#       <th>OCTOBER 2023</th>
#       <td>750.531</td>
# ...

# %% [markdown]
# ## 4. Spatial Analysis

# %%
# Figure 2 — Spatial distribution. Top 3 hotspots labelled.

# %% [markdown]
# ### Top 10 Highest CO₂ Stations

# %%
# Top 10 stations
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Mean CO₂ (ppm)</th>
#       <th>Std</th>
#     </tr>
#     <tr>
#       <th>Station</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Marine Base</th>
#       <td>853.92</td>
#       <td>16.49</td>
#     </tr>
#     <tr>
#       <th>Trans Amadi</th>
#       <td>827.82</td>
#       <td>15.21</td>
#     </tr>
#     <tr>
#       <th>Elelenwo</th>
#       <td>800.16</td>
#       <td>20.66</td>
#     </tr>
#     <tr>
#       <th>Aluu</th>
#       <td>796.72</td>
#       <td>62.89</td>
#     </tr>
#     <tr>
#       <th>Woji</th>
#       <td>794.59</td>
#       <td>15.64</td>
#     </tr>
#     <tr>
#       <th>Eligbam</th>
#       <td>788.39</td>
#       <td>15.45</td>
#     </tr>
#     <tr>
#       <th>Rumuigbo</th>
#       <td>784.49</td>
#       <td>14.68</td>
#     </tr>
#     <tr>
#       <th>Igwuruta</th>
# ...

# %% [markdown]
# ### Bottom 10 Lowest CO₂ Stations

# %%
# Bottom 10 stations
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Mean CO₂ (ppm)</th>
#       <th>Std</th>
#     </tr>
#     <tr>
#       <th>Station</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Nkpolu</th>
#       <td>696.93</td>
#       <td>52.70</td>
#     </tr>
#     <tr>
#       <th>Mgbuogba</th>
#       <td>713.32</td>
#       <td>47.19</td>
#     </tr>
#     <tr>
#       <th>Rumuwoji</th>
#       <td>725.26</td>
#       <td>14.35</td>
#     </tr>
#     <tr>
#       <th>Rukpakwolusi</th>
#       <td>728.29</td>
#       <td>12.79</td>
#     </tr>
#     <tr>
#       <th>Ada-George Road</th>
#       <td>730.52</td>
#       <td>13.43</td>
#     </tr>
#     <tr>
#       <th>Rumuokwurusi</th>
#       <td>735.67</td>
#       <td>12.77</td>
#     </tr>
#     <tr>
#       <th>Eligbolo</th>
#       <td>741.12</td>
#       <td>14.12</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## 5. Statistical Tests

# %% [markdown]
# ### 5.1 Shapiro-Wilk Normality Test

# %%
# Shapiro-Wilk
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Variable</th>
#       <th>W</th>
#       <th>p-value</th>
#       <th>Normal?</th>
#       <th>Sig</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CO2_</td>
#       <td>0.9512</td>
#       <td>0.000000</td>
#       <td>No</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>N2O</td>
#       <td>0.9698</td>
#       <td>0.000000</td>
#       <td>No</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CH4</td>
#       <td>0.6848</td>
#       <td>0.000000</td>
#       <td>No</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>O3</td>
#       <td>0.0536</td>
#       <td>0.000000</td>
#       <td>No</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>CO</td>
#       <td>0.9868</td>
#       <td>0.000170</td>
#       <td>No</td>
# ...

# %% [markdown]
# ### 5.2 Kruskal-Wallis H-Test (Are monthly distributions different?)

# %%
# Kruskal-Wallis
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pollutant</th>
#       <th>H-statistic</th>
#       <th>p-value</th>
#       <th>Significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CO2_</td>
#       <td>132.8736</td>
#       <td>0.0</td>
#       <td>✅ Yes (p&lt;0.001)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>N2O</td>
#       <td>164.6531</td>
#       <td>0.0</td>
#       <td>✅ Yes (p&lt;0.001)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CH4</td>
#       <td>424.4207</td>
#       <td>0.0</td>
#       <td>✅ Yes (p&lt;0.001)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CO</td>
#       <td>96.1388</td>
#       <td>0.0</td>
#       <td>✅ Yes (p&lt;0.001)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5.3 Year-over-Year Change: 2023 vs 2024-25 (Mann-Whitney U)

# %%
# Mann-Whitney YoY
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pollutant</th>
#       <th>Mean 2023</th>
#       <th>Mean 2024-25</th>
#       <th>% Change</th>
#       <th>p-value</th>
#       <th>Sig</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CO2_</td>
#       <td>752.508</td>
#       <td>772.891</td>
#       <td>+2.7%</td>
#       <td>0.0</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>N2O</td>
#       <td>0.067</td>
#       <td>0.073</td>
#       <td>+9.2%</td>
#       <td>0.0</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CH4</td>
#       <td>2.129</td>
#       <td>6.898</td>
#       <td>+224.0%</td>
#       <td>0.0</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CO</td>
#       <td>17.194</td>
#       <td>20.452</td>
#       <td>+19.0%</td>
#       <td>0.0</td>
#       <td>***</td>
# ...

# %% [markdown]
# > 🚨 **CH₄ increased +224% between 2023 and 2024–25 (p < 0.001)** — the most critical finding of this study.

# %% [markdown]
# ## 6. Correlation Analysis

# %%
# Figure 3 — Spearman correlation heatmap & CO₂ box plots

# %% [markdown]
# ### Full Spearman Correlation Matrix

# %%
# Spearman correlation matrix
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CO₂</th>
#       <th>N₂O</th>
#       <th>CH₄</th>
#       <th>O₃</th>
#       <th>CO</th>
#       <th>Temp</th>
#       <th>Humidity</th>
#       <th>Wind Speed</th>
#       <th>Rainfall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CO₂</th>
#       <td>1.000</td>
#       <td>0.558</td>
#       <td>0.565</td>
#       <td>0.583</td>
#       <td>0.324</td>
#       <td>0.447</td>
#       <td>-0.332</td>
#       <td>0.015</td>
#       <td>-0.150</td>
#     </tr>
#     <tr>
#       <th>N₂O</th>
#       <td>0.558</td>
#       <td>1.000</td>
#       <td>0.280</td>
#       <td>0.412</td>
#       <td>0.252</td>
#       <td>0.299</td>
#       <td>-0.274</td>
#       <td>0.080</td>
#       <td>-0.218</td>
#     </tr>
#     <tr>
#       <th>CH₄</th>
#       <td>0.565</td>
#       <td>0.280</td>
#       <td>1.000</td>
#       <td>0.525</td>
# ...

# %% [markdown]
# ### Significant Pollutant × Meteorology Correlations

# %%
# Significant correlations
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pollutant</th>
#       <th>Meteorology</th>
#       <th>Spearman r</th>
#       <th>p-value</th>
#       <th>Direction</th>
#       <th>Sig</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CO₂ (ppm)</td>
#       <td>Temperature</td>
#       <td>0.4465</td>
#       <td>0.000000</td>
#       <td>↑ Positive</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>CO₂ (ppm)</td>
#       <td>Humidity</td>
#       <td>-0.3315</td>
#       <td>0.000000</td>
#       <td>↓ Negative</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CO₂ (ppm)</td>
#       <td>Rainfall</td>
#       <td>-0.1498</td>
#       <td>0.000308</td>
#       <td>↓ Negative</td>
#       <td>***</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>N₂O (ppm)</td>
#       <td>Temperature</td>
#       <td>0.2991</td>
# ...

# %% [markdown]
# ## 7. Machine Learning Results
# 5-fold cross-validation (n_splits=5, shuffle=True, random_state=42)

# %%
# Full CV results
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Target</th>
#       <th>Model</th>
#       <th>R² mean</th>
#       <th>R² ±SD</th>
#       <th>RMSE mean</th>
#       <th>RMSE ±SD</th>
#       <th>MAE mean</th>
#       <th>MAE ±SD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CO₂ (ppm)</td>
#       <td>Linear Regression</td>
#       <td>0.2591</td>
#       <td>0.0280</td>
#       <td>28.6648</td>
#       <td>1.8887</td>
#       <td>22.0528</td>
#       <td>0.7713</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>CO₂ (ppm)</td>
#       <td>Ridge Regression</td>
#       <td>0.2592</td>
#       <td>0.0278</td>
#       <td>28.6631</td>
#       <td>1.8928</td>
#       <td>22.0469</td>
#       <td>0.7721</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CO₂ (ppm)</td>
#       <td>Random Forest</td>
#       <td>0.6600</td>
#       <td>0.0585</td>
# ...

# %%
# Figure 4 — Model comparison. Gradient Boosting wins across all pollutants.

# %% [markdown]
# ## 8. Feature Importance
# Random Forest Mean Decrease in Impurity (MDI). Higher = more predictive.

# %%
# Figure 5 — Feature importance. Temperature & location dominate CO₂; Month dominates CH₄.

# %%
# Feature importance table
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Target</th>
#       <th>Feature</th>
#       <th>Importance (MDI)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CO₂ (ppm)</td>
#       <td>Temperature</td>
#       <td>0.3349</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>CO₂ (ppm)</td>
#       <td>Latitude</td>
#       <td>0.2534</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CO₂ (ppm)</td>
#       <td>Longitude</td>
#       <td>0.1865</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CO₂ (ppm)</td>
#       <td>Month</td>
#       <td>0.1015</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>CO₂ (ppm)</td>
#       <td>Humidity</td>
#       <td>0.0643</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>CO₂ (ppm)</td>
#       <td>Wind Speed</td>
#       <td>0.0379</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>CO₂ (ppm)</td>
# ...

# %% [markdown]
# ## 9. Observed vs Predicted
# Gradient Boosting out-of-fold predictions (5-fold CV)

# %%
# Figure 6 — Observed vs predicted. Points on 1:1 line = perfect prediction.

# %% [markdown]
# ### Prediction Accuracy Summary (Gradient Boosting)

# %%
# Prediction summary
# Out:
# <table class="dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pollutant</th>
#       <th>R²</th>
#       <th>RMSE</th>
#       <th>MAE</th>
#       <th>Max Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CO₂ (ppm)</td>
#       <td>0.6990</td>
#       <td>18.4173</td>
#       <td>11.9729</td>
#       <td>166.8998</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>CH₄ (ppm)</td>
#       <td>0.8617</td>
#       <td>1.5622</td>
#       <td>0.7662</td>
#       <td>8.5573</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CO (ppm)</td>
#       <td>0.8155</td>
#       <td>2.4480</td>
#       <td>1.8412</td>
#       <td>12.7648</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 10. Key Findings Summary
#
# ---
#
# ### 🏆 Best Model (Gradient Boosting) — 5-Fold CV
#
# | Pollutant | R² | RMSE | MAE |
# |-----------|-----|------|-----|
# | **CO₂** | **0.7014** | 18.1816 ppm | 11.9730 ppm |
# | **N₂O** | **0.6881** | 0.006614 ppm | 0.004854 ppm |
# | **CH₄** | **0.8665** | 1.5067 ppm | 0.7667 ppm |
# | **CO**  | **0.8140** | 2.4385 ppm | 1.8410 ppm |
#
# ---
#
# ### 📈 Year-over-Year Pollution Increase (2023 → 2024-25)
#
# | Pollutant | Change | p-value |
# |-----------|--------|---------|
# | **CH₄** | 🚨 **+224.0%** | < 0.001 |
# | **CO**  | ⚠️ **+19.0%**  | < 0.001 |
# | **N₂O** | ⚠️ **+9.2%**   | < 0.001 |
# | **CO₂** | 📌 **+2.7%**   | < 0.001 |
#
# ---
#
# ### 📍 Top Pollution Hotspots (Mean CO₂)
#
# | Rank | Station | Mean CO₂ (ppm) | Land Use |
# |------|---------|----------------|----------|
# | 1 🔴 | **Marine Base** | 853.92 | Industrial/Petrochemical |
# | 2 🔴 | **Trans Amadi** | 827.82 | Industrial Layout |
# | 3 🟠 | **Elelenwo**    | 800.16 | Mixed/Commercial |
#
# ---
#
# ### 🔑 Top Predictors by Pollutant (Random Forest MDI)
#
# | Pollutant | #1 Predictor | #2 Predictor | Combined % |
# |-----------|-------------|-------------|------------|
# | CO₂ | Temperature (32.3%) | Latitude (25.3%) | 57.6% |
# | CH₄ | Month (48.2%)       | Latitude (37.2%) | 85.4% |
# | N₂O | Month (27.2%)       | Latitude (25.8%) | 53.0% |
# | CO  | Longitude (37.7%)   | Latitude (21.0%) | 58.7% |
#
# ---
# *Pipeline: scikit-learn 1.8 · scipy 1.17 · pandas · matplotlib*
# *Data: Port Harcourt Air Quality Monitoring Network, 2023–2025*
