# %% [markdown]
# # 🌍 Geospatial Machine Learning for Air Pollution Prediction
# ## Using Multivariate Environmental Data — Port Harcourt, Nigeria (2023–2025)
#
# **Journal:** Environmental Science and Pollution Research (Springer)
# **Study Area:** 48 monitoring stations, Port Harcourt, Rivers State, Nigeria
# **Period:** August 2023 – January 2025 (12 months)
# **Dataset:** 576 station-month observations
#
# ---
#
# ## 📌 Table of Contents
# 1. [Dataset Overview](#1-dataset-overview)
# 2. [Descriptive Statistics](#2-descriptive-statistics)
# 3. [Temporal Trends](#3-temporal-trends)
# 4. [Spatial Analysis](#4-spatial-analysis)
# 5. [Statistical Tests](#5-statistical-tests)
# 6. [Correlation Analysis](#6-correlation-analysis)
# 7. [Machine Learning Models](#7-machine-learning-models)
# 8. [Feature Importance](#8-feature-importance)
# 9. [Observed vs Predicted](#9-observed-vs-predicted)
# 10. [Key Findings Summary](#10-key-findings-summary)

# %% [markdown]
# ## 1. Dataset Overview

# %% [markdown]
# - **Total observations:** 576
# - **Monitoring stations:** 48
# - **Months covered:** 12
# - **Target pollutants:** CO₂, N₂O, CH₄, O₃, CO
# - **Predictor features:** Latitude, Longitude, Month, Temperature, Humidity, Wind Speed, Rainfall
# - **Missing values:** None
# - **Geographic extent:** Port Harcourt, Rivers State, Nigeria (4.74°–4.95°N, 6.92°–7.08°E)

# %% [markdown]
# ## 2. Descriptive Statistics

# %% [markdown]
# |                  |   count |     mean |     std |      min |      25% |      50% |      75% |      max |
# |:-----------------|--------:|---------:|--------:|---------:|---------:|---------:|---------:|---------:|
# | CO₂ (ppm)        |     576 | 764.398  | 33.599  | 607.4    | 745.9    | 764.4    | 782.133  | 879.3    |
# | N₂O (ppm)        |     576 |   0.0703 |  0.0121 |   0.0243 |   0.064  |   0.07   |   0.0768 |   0.1107 |
# | CH₄ (ppm)        |     576 |   4.9109 |  4.2043 |   1.0033 |   1.9367 |   4.0233 |   6.6292 |  27.11   |
# | O₃ (ppm)         |     576 |   0.1748 |  0.7781 |   0.01   |   0.1065 |   0.1267 |   0.1514 |  14.8177 |
# | CO (ppm)         |     576 |  19.0945 |  5.7048 |   1.3467 |  15.695  |  18.91   |  22.8483 |  33.89   |
# | Temperature (°C) |     576 |  30.785  |  2.5066 |  23.6333 |  29.3333 |  30.8667 |  32.3333 |  40.4    |
# | Humidity (%)     |     576 |  77.5653 |  9.934  |  41.1    |  72      |  78.6667 |  84.3333 |  98      |
# | Wind Speed (m/s) |     576 |   0.3364 |  0.5044 |   0      |   0      |   0.1    |   0.4333 |   3.1667 |
# | Rainfall (mm/hr) |     576 |   0.4992 |  1.7985 |   0      |   0      |   0      |   0      |  19.8    |

# %% [markdown]
# ## 3. Temporal Trends

# %% [markdown]
# ![Figure 3: Temporal Trends — monthly mean concentrations with linear trend overlay. Blue=2023, Red=2024-25.](data:image/png;base64,...)
#
# *Figure 3: Temporal Trends — monthly mean concentrations with linear trend overlay. Blue=2023, Red=2024-25.*

# %% [markdown]
# ### Monthly Mean Concentrations

# %% [markdown]
# | Month          |    CO2_ |   N2O |   CH4 |    O3 |     CO |   Temperature(°C) |   Humidity(%) |
# |:---------------|--------:|------:|------:|------:|-------:|------------------:|--------------:|
# | AUGUST 2023    | 737.827 | 0.06  | 2.159 | 0.111 | 16.582 |            28.741 |        81.757 |
# | SEPTEMBER 2023 | 762.635 | 0.069 | 2.136 | 0.124 | 16.882 |            29.431 |        80.986 |
# | OCTOBER 2023   | 750.531 | 0.064 | 2.052 | 0.105 | 15.245 |            28.769 |        82.477 |
# | NOVEMBER 2023  | 752.317 | 0.07  | 2.156 | 0.115 | 17.404 |            29.442 |        78.465 |
# | DECEMBER 2023  | 759.228 | 0.072 | 2.142 | 0.352 | 19.856 |            31.116 |        77.021 |
# | JANUARY 2024   | 763.578 | 0.089 | 2.272 | 0.447 | 20.064 |            31.035 |        74.625 |
# | AUGUST 2024    | 754.568 | 0.066 | 5.454 | 0.13  | 17.835 |            30.538 |        79.938 |
# | SEPTEMBER 2024 | 769.781 | 0.07  | 6.478 | 0.123 | 19.51  |            31.369 |        77.993 |
# | OCTOBER 2024   | 772.51  | 0.07  | 8.346 | 0.138 | 19.95  |            31.444 |        80.924 |
# | NOVEMBER 2024  | 778.712 | 0.071 | 8.583 | 0.145 | 21.154 |            31.844 |        75.792 |
# | DECEMBER 2024  | 783.583 | 0.071 | 8.734 | 0.154 | 22.086 |            32.01  |        77.104 |
# | JANUARY 2025   | 787.506 | 0.072 | 8.418 | 0.155 | 22.567 |            33.681 |        63.703 |

# %% [markdown]
# ## 4. Spatial Analysis

# %% [markdown]
# ![Figure 4: Spatial distribution of mean pollutant concentrations. Top 3 hotspots labelled.](data:image/png;base64,...)
#
# *Figure 4: Spatial distribution of mean pollutant concentrations. Top 3 hotspots labelled.*

# %% [markdown]
# ### Top 10 Highest CO₂ Monitoring Stations

# %% [markdown]
# | Station     |   Mean CO₂ (ppm) |   Std CO₂ (ppm) |
# |:------------|-----------------:|----------------:|
# | Marine Base |           853.92 |           16.49 |
# | Trans Amadi |           827.82 |           15.21 |
# | Elelenwo    |           800.16 |           20.66 |
# | Aluu        |           796.72 |           62.89 |
# | Woji        |           794.59 |           15.64 |
# | Eligbam     |           788.39 |           15.45 |
# | Rumuigbo    |           784.49 |           14.68 |
# | Igwuruta    |           784.11 |           16.16 |
# | Rumurolu    |           783.04 |           18.95 |
# | Elekahia    |           779.96 |           15.19 |

# %% [markdown]
# ### Bottom 10 Lowest CO₂ Monitoring Stations

# %% [markdown]
# | Station         |   Mean CO₂ (ppm) |   Std CO₂ (ppm) |
# |:----------------|-----------------:|----------------:|
# | Nkpolu          |           696.93 |           52.7  |
# | Mgbuogba        |           713.32 |           47.19 |
# | Rumuwoji        |           725.26 |           14.35 |
# | Rukpakwolusi    |           728.29 |           12.79 |
# | Ada-George Road |           730.52 |           13.43 |
# | Rumuokwurusi    |           735.67 |           12.77 |
# | Eligbolo        |           741.12 |           14.12 |
# | Rumuokoro       |           742.45 |           13.64 |
# | Egbelu          |           743.28 |           14.15 |
# | Rumuoqonoma     |           744.92 |           13.85 |

# %% [markdown]
# ## 5. Statistical Tests

# %% [markdown]
# ### 5.1 Shapiro-Wilk Normality Test

# %% [markdown]
# |    | Variable        |      W |   p-value | Normal (p≥0.05)   | Sig   |
# |---:|:----------------|-------:|----------:|:------------------|:------|
# |  0 | CO2_            | 0.9512 |   0       | No                | ***   |
# |  1 | N2O             | 0.9698 |   0       | No                | ***   |
# |  2 | CH4             | 0.6848 |   0       | No                | ***   |
# |  3 | O3              | 0.0536 |   0       | No                | ***   |
# |  4 | CO              | 0.9868 |   0.00017 | No                | ***   |
# |  5 | Temperature(°C) | 0.9846 |   3.9e-05 | No                | ***   |
# |  6 | Humidity(%)     | 0.9738 |   0       | No                | ***   |

# %% [markdown]
# ### 5.2 Kruskal-Wallis H-Test (Seasonal Differences)

# %% [markdown]
# |    | Pollutant   |   H-statistic |   p-value | Significant   |
# |---:|:------------|--------------:|----------:|:--------------|
# |  0 | CO2_        |      132.874  |         0 | Yes (p<0.001) |
# |  1 | N2O         |      164.653  |         0 | Yes (p<0.001) |
# |  2 | CH4         |      424.421  |         0 | Yes (p<0.001) |
# |  3 | CO          |       96.1388 |         0 | Yes (p<0.001) |

# %% [markdown]
# ### 5.3 Year-over-Year Comparison (2023 vs 2024-25) — Mann-Whitney U

# %% [markdown]
# |    | Pollutant   |   Mean 2023 |   Mean 2024-25 | % Change   |   U-stat |   p-value | Sig   |
# |---:|:------------|------------:|---------------:|:-----------|---------:|----------:|:------|
# |  0 | CO2_        |    752.508  |       772.891  | +2.7%      |  23371   |         0 | ***   |
# |  1 | N2O         |      0.0667 |         0.0728 | +9.2%      |  28208   |         0 | ***   |
# |  2 | CH4         |      2.1291 |         6.8978 | +224.0%    |   5716.5 |         0 | ***   |
# |  3 | CO          |     17.1938 |        20.4522 | +19.0%     |  26312.5 |         0 | ***   |

# %% [markdown]
# > 🚨 **CH₄ increased by +224% between 2023 and 2024-25 (p < 0.001)** — a critical finding requiring urgent attribution analysis.

# %% [markdown]
# ## 6. Correlation Analysis

# %% [markdown]
# ![Figure 1: (Left) Spearman correlation heatmap. (Right) Monthly CO₂ box plots. Blue=2023, Red=2024-25.](data:image/png;base64,...)
#
# *Figure 1: (Left) Spearman correlation heatmap. (Right) Monthly CO₂ box plots. Blue=2023, Red=2024-25.*

# %% [markdown]
# ### Spearman Correlation Table

# %% [markdown]
# |          |    CO₂ |    N₂O |    CH₄ |     O₃ |     CO |   Temp |   Humidity |    Wind |   Rainfall |
# |          |        |        |        |        |        |        |            |   Speed |            |
# |:---------|-------:|-------:|-------:|-------:|-------:|-------:|-----------:|--------:|-----------:|
# | CO₂      |  1     |  0.558 |  0.565 |  0.583 |  0.324 |  0.447 |     -0.332 |   0.015 |     -0.15  |
# | N₂O      |  0.558 |  1     |  0.28  |  0.412 |  0.252 |  0.299 |     -0.274 |   0.08  |     -0.218 |
# | CH₄      |  0.565 |  0.28  |  1     |  0.525 |  0.377 |  0.523 |     -0.307 |   0.01  |     -0.123 |
# | O₃       |  0.583 |  0.412 |  0.525 |  1     |  0.369 |  0.357 |     -0.207 |   0.006 |     -0.166 |
# | CO       |  0.324 |  0.252 |  0.377 |  0.369 |  1     |  0.38  |     -0.28  |   0.043 |     -0.35  |
# | Temp     |  0.447 |  0.299 |  0.523 |  0.357 |  0.38  |  1     |     -0.598 |   0.172 |     -0.301 |
# | Humidity | -0.332 | -0.274 | -0.307 | -0.207 | -0.28  | -0.598 |      1     |  -0.125 |      0.42  |
# | Wind     |  0.015 |  0.08  |  0.01  |  0.006 |  0.043 |  0.172 |     -0.125 |   1     |     -0.034 |
# | Speed    |        |        |        |        |        |        |            |         |            |
# | Rainfall | -0.15  | -0.218 | -0.123 | -0.166 | -0.35  | -0.301 |      0.42  |  -0.034 |      1     |

# %% [markdown]
# ## 7. Machine Learning Models
#
# 5-fold cross-validation results for all five models across all target pollutants.

# %% [markdown]
# |    | Target    | Model             |   R² (mean) |   R² (±SD) |   RMSE (mean) |   RMSE (±SD) |   MAE (mean) |
# |---:|:----------|:------------------|------------:|-----------:|--------------:|-------------:|-------------:|
# |  0 | CO₂ (ppm) | Linear Regression |      0.2591 |     0.028  |       28.6648 |       1.8887 |      22.0528 |
# |  1 | CO₂ (ppm) | Ridge Regression  |      0.2592 |     0.0278 |       28.6631 |       1.8928 |      22.0469 |
# |  2 | CO₂ (ppm) | Random Forest     |      0.66   |     0.0585 |       19.436  |       2.6671 |      13.0782 |
# |  3 | CO₂ (ppm) | Gradient Boosting |      0.7014 |     0.07   |       18.1816 |       2.9479 |      11.973  |
# |  4 | CO₂ (ppm) | SVR               |      0.4181 |     0.0636 |       25.5092 |       3.3652 |      18.093  |
# |  5 | N₂O (ppm) | Linear Regression |      0.0703 |     0.0387 |        0.0115 |       0.0006 |       0.0085 |
# |  6 | N₂O (ppm) | Ridge Regression  |      0.0704 |     0.0386 |        0.0115 |       0.0006 |       0.0085 |
# |  7 | N₂O (ppm) | Random Forest     |      0.6067 |     0.1067 |        0.0074 |       0.0011 |       0.0051 |
# |  8 | N₂O (ppm) | Gradient Boosting |      0.6881 |     0.065  |        0.0066 |       0.0007 |       0.0049 |
# |  9 | N₂O (ppm) | SVR               |     -0.1298 |     0.1288 |        0.0126 |       0.0004 |       0.0094 |
# | 10 | CH₄ (ppm) | Linear Regression |      0.4296 |     0.041  |        3.1242 |       0.5612 |       1.9694 |
# | 11 | CH₄ (ppm) | Ridge Regression  |      0.4297 |     0.041  |        3.1239 |       0.5619 |       1.9679 |
# | 12 | CH₄ (ppm) | Random Forest     |      0.8569 |     0.0588 |        1.536  |       0.4814 |       0.7223 |
# | 13 | CH₄ (ppm) | Gradient Boosting |      0.8665 |     0.0402 |        1.5067 |       0.4164 |       0.7667 |
# | 14 | CH₄ (ppm) | SVR               |      0.6171 |     0.1119 |        2.5416 |       0.6454 |       1.3145 |
# | 15 | CO (ppm)  | Linear Regression |      0.1888 |     0.0754 |        5.0969 |       0.2129 |       4.0138 |
# | 16 | CO (ppm)  | Ridge Regression  |      0.189  |     0.0752 |        5.0964 |       0.2128 |       4.0134 |
# | 17 | CO (ppm)  | Random Forest     |      0.7837 |     0.0172 |        2.6344 |       0.1275 |       1.9888 |
# | 18 | CO (ppm)  | Gradient Boosting |      0.814  |     0.0284 |        2.4385 |       0.2128 |       1.841  |
# | 19 | CO (ppm)  | SVR               |      0.4655 |     0.0889 |        4.1186 |       0.1599 |       3.133  |

# %% [markdown]
# ![Figure 2: Model comparison — R² scores (mean ± SD) across five ML algorithms. Gradient Boosting consistently achieves the highest performance.](data:image/png;base64,...)
#
# *Figure 2: Model comparison — R² scores (mean ± SD) across five ML algorithms. Gradient Boosting consistently achieves the highest performance.*

# %% [markdown]
# ## 8. Feature Importance
#
# Random Forest Mean Decrease in Impurity (MDI) importance scores — higher = more predictive.

# %% [markdown]
# ![Figure 5: Random Forest feature importance. Temperature & geospatial coordinates dominate for CO₂; temporal index dominates for CH₄.](data:image/png;base64,...)
#
# *Figure 5: Random Forest feature importance. Temperature & geospatial coordinates dominate for CO₂; temporal index dominates for CH₄.*

# %% [markdown]
# |    | Target    | Feature     |   Importance (MDI) |
# |---:|:----------|:------------|-------------------:|
# |  0 | CO₂ (ppm) | Temperature |             0.3349 |
# |  1 | CO₂ (ppm) | Latitude    |             0.2534 |
# |  2 | CO₂ (ppm) | Longitude   |             0.1865 |
# |  3 | CO₂ (ppm) | Month       |             0.1015 |
# |  4 | CO₂ (ppm) | Humidity    |             0.0643 |
# |  5 | CO₂ (ppm) | Wind Speed  |             0.0379 |
# |  6 | CO₂ (ppm) | Rainfall    |             0.0215 |
# |  7 | N₂O (ppm) | Month       |             0.2718 |
# |  8 | N₂O (ppm) | Latitude    |             0.2578 |
# |  9 | N₂O (ppm) | Longitude   |             0.1633 |
# | 10 | N₂O (ppm) | Temperature |             0.1334 |
# | 11 | N₂O (ppm) | Humidity    |             0.073  |
# | 12 | N₂O (ppm) | Wind Speed  |             0.07   |
# | 13 | N₂O (ppm) | Rainfall    |             0.0307 |
# | 14 | CH₄ (ppm) | Month       |             0.4818 |
# | 15 | CH₄ (ppm) | Latitude    |             0.372  |
# | 16 | CH₄ (ppm) | Temperature |             0.0635 |
# | 17 | CH₄ (ppm) | Longitude   |             0.0431 |
# | 18 | CH₄ (ppm) | Humidity    |             0.0273 |
# | 19 | CH₄ (ppm) | Wind Speed  |             0.0108 |
# | 20 | CH₄ (ppm) | Rainfall    |             0.0015 |
# | 21 | CO (ppm)  | Longitude   |             0.3766 |
# | 22 | CO (ppm)  | Latitude    |             0.2101 |
# | 23 | CO (ppm)  | Month       |             0.1271 |
# | 24 | CO (ppm)  | Temperature |             0.0879 |
# | 25 | CO (ppm)  | Rainfall    |             0.0848 |
# | 26 | CO (ppm)  | Humidity    |             0.0804 |
# | 27 | CO (ppm)  | Wind Speed  |             0.0331 |

# %% [markdown]
# ## 9. Observed vs Predicted (Gradient Boosting — 5-Fold OOF)

# %% [markdown]
# ![Figure 6: Observed vs. predicted scatter plots (Gradient Boosting OOF). Points along 1:1 line indicate high fidelity.](data:image/png;base64,...)
#
# *Figure 6: Observed vs. predicted scatter plots (Gradient Boosting OOF). Points along 1:1 line indicate high fidelity.*

# %% [markdown]
# ## 10. Key Findings Summary
#
# ### 🏆 Best Model Performance (Gradient Boosting)
#
# | Pollutant | R² | RMSE | MAE |
# |-----------|-----|------|-----|
# | CO₂ | **0.7014** | 18.1816 ppm | 11.9730 ppm |
# | N₂O | **0.6881** | 0.0066 ppm | 0.0049 ppm |
# | CH₄ | **0.8665** | 1.5067 ppm | 0.7667 ppm |
# | CO  | **0.8140** | 2.4385 ppm | 1.8410 ppm |
#
# ### 📈 Year-over-Year Pollution Increase (2023 → 2024-25)
#
# | Pollutant | Change | Significance |
# |-----------|--------|--------------|
# | CH₄ | **+224.0%** 🚨 | p < 0.001 |
# | CO  | **+19.0%** | p < 0.001 |
# | N₂O | **+9.2%**  | p < 0.001 |
# | CO₂ | **+2.7%**  | p < 0.001 |
#
# ### 📍 Top Pollution Hotspots
#
# | Rank | Station | Mean CO₂ (ppm) |
# |------|---------|----------------|
# | 1 | **Marine Base** | 853.92 |
# | 2 | **Trans Amadi** | 827.82 |
# | 3 | **Elelenwo** | 800.16 |
#
# ### 🔑 Key Predictor Rankings
# - **CO₂**: Temperature (32.3%) > Latitude (25.3%) > Longitude (18.7%)
# - **CH₄**: Month (48.2%) > Latitude (37.2%) — time-varying gas flaring
# - **CO**: Longitude (37.7%) > Latitude (21.0%) — east-west traffic gradient
#
# ---
# *Generated with scikit-learn | Data: Port Harcourt Air Quality Monitoring Network*
